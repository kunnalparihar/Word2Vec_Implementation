# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile
import tensorflow as tf

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
from tensorflow.contrib.tensorboard.plugins import projector

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data


vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# 2 of -> 195 term
# 2 of -> 3134 abuse
# 3134 abuse -> 2 of
# 3134 abuse -> 46 first
# 46 first -> 3134 abuse
# 46 first -> 59 used
# 59 used -> 46 first
# 59 used -> 156 against
# Initialized
# Average loss at step  0 :  271.2423095703125
# Nearest to about: gst, urine, cutting, penderecki, heldenplatz, dischord, airports, cabell,
# Nearest to it: husband, growth, feb, valdes, maccabean, describes, employ, beattie,
# Nearest to but: prospect, elementals, riots, tort, conger, perplexed, uma, assembling,
# Nearest to during: faintly, comparably, echoes, spine, othniel, trinity, reliefs, irregulars,
# Nearest to not: mk, semi, geirr, vultures, stwertka, jumping, restaurant, feodor,
# Nearest to an: fifths, ilp, denies, cyclase, newly, aurelianus, stonework, tetrapods,
# Nearest to than: qualcomm, kampuchea, torsion, pubns, aircrew, aluminum, inconsistent, della,
# Nearest to has: corrado, proportionately, kool, garrick, orators, kiang, sutra, dalnet,
# Nearest to i: douglas, fuzes, modernists, hfs, fronti, rte, evangelista, suppliers,
# Nearest to he: peptide, actor, mahayana, want, drums, brentwood, reflection, tungsten,
# Nearest to into: luisa, valiantly, invader, converges, informa, resided, illegally, collins,
# Nearest to seven: albret, deshima, tude, haber, materiel, compacted, chiba, strung,
# Nearest to often: ris, hillsides, kripke, topaz, laches, monsters, sparkle, commanded,
# Nearest to will: kingston, base, janus, astrakhan, loser, xia, tenet, strives,
# Nearest to world: booed, borderline, monologues, pederasty, wasteful, regress, runes, heb,
# Nearest to were: squandered, hippos, scorer, fountainhead, garbo, ionic, caecilius, dyeing,
# Average loss at step  2000 :  113.6919352941513
# Average loss at step  4000 :  52.654893144845964
# Average loss at step  6000 :  33.129528771162036
# Average loss at step  8000 :  23.286600954532624
# Average loss at step  10000 :  17.9355588285923
# Nearest to about: UNK, archie, afx, pseudocode, bush, zero, heldenplatz, threat,
# Nearest to it: growth, he, actions, archie, saratoga, describes, this, a,
# Nearest to but: and, prospect, riots, themes, designers, mob, room, pollination,
# Nearest to during: antimatter, infection, paintings, surrounded, victor, machine, championship, presented,
# Nearest to not: restaurant, semi, paints, mk, casualties, george, quantum, unstable,
# Nearest to an: the, academy, southwest, denies, seen, fitness, gb, bckgr,
# Nearest to than: inconsistent, argentina, aluminum, mall, torsion, actor, kevin, established,
# Nearest to has: kool, happened, is, proportionately, say, lymphoma, initiating, irrelevant,
# Nearest to i: he, douglas, gmt, instructions, fox, gods, interested, five,
# Nearest to he: i, and, it, actor, dddddd, stay, they, reduce,
# Nearest to into: resided, in, collins, nationalist, associated, tennessee, walked, decade,
# Nearest to seven: nine, zero, eight, bose, archie, phi, one, uke,
# Nearest to often: hillsides, potato, commanded, inhabitants, trophy, mead, ris, continuity,
# Nearest to will: base, and, voluntary, gore, saga, webster, sales, loser,
# Nearest to world: bckgr, solf, francis, thinking, dogs, reginald, ss, judgment,
# Nearest to were: mathbf, nearer, secular, bckgr, fountainhead, gods, emerged, invariably,
# Average loss at step  12000 :  14.249870302081108
# Average loss at step  14000 :  11.670961405515671
# Average loss at step  16000 :  10.019305693387984
# Average loss at step  18000 :  8.423005368590355
# Average loss at step  20000 :  7.987420618772506
# Nearest to about: agouti, ibelin, nine, UNK, archie, savage, circ, five,
# Nearest to it: he, this, which, growth, russel, agouti, governors, actions,
# Nearest to but: and, circ, themes, that, mob, prospect, or, is,
# Nearest to during: in, infection, paintings, surrounded, and, echoes, antimatter, untested,
# Nearest to not: restaurant, paints, semi, quantum, penning, trinitarian, it, avoided,
# Nearest to an: the, seen, fitness, academy, aurelianus, completely, denies, agouti,
# Nearest to than: inconsistent, dasyprocta, agouti, argentina, aluminum, torsion, circ, or,
# Nearest to has: is, was, kool, have, were, naur, bearers, are,
# Nearest to i: douglas, lascaris, he, instructions, five, truetype, suppliers, accordance,
# Nearest to he: it, they, and, i, who, noodles, dddddd, nine,
# Nearest to into: luisa, in, resided, nationalist, as, to, decade, for,
# Nearest to seven: nine, eight, zero, four, six, three, five, one,
# Nearest to often: continuity, hillsides, builder, ris, hbox, copied, potato, agouti,
# Nearest to will: base, and, amazonas, would, apatosaurus, webster, loser, voluntary,
# Nearest to world: bckgr, amazonas, trapezohedron, solf, reginald, dogs, epiphanius, francis,
# Nearest to were: are, was, is, and, in, as, dasyprocta, solon,
# Average loss at step  22000 :  7.086692750334739
# Average loss at step  24000 :  6.891421240389347
# Average loss at step  26000 :  6.7592695803642275
# Average loss at step  28000 :  6.3771579174995425
# Average loss at step  30000 :  5.962593074083328
# Nearest to about: ibelin, agouti, reddy, five, six, sufficiently, nine, savage,
# Nearest to it: he, this, which, there, she, aba, agouti, tnf,
# Nearest to but: and, tnf, circ, that, or, assembled, agouti, themes,
# Nearest to during: in, and, untested, paintings, on, from, mishnayot, surrounded,
# Nearest to not: restaurant, paints, it, to, semi, penning, also, avoided,
# Nearest to an: the, seen, cellist, fitness, completely, minoan, fifths, aorta,
# Nearest to than: inconsistent, or, humidity, and, dasyprocta, agouti, argentina, aluminum,
# Nearest to has: is, was, had, have, kool, were, meridians, bearers,
# Nearest to i: fuzes, douglas, he, lascaris, five, apc, astonishing, instructions,
# Nearest to he: it, they, who, she, tnf, i, and, dddddd,
# Nearest to into: in, luisa, to, from, resided, decade, upon, by,
# Nearest to seven: eight, nine, four, five, six, zero, three, circ,
# Nearest to often: hillsides, continuity, also, copied, builder, which, hbox, agouti,
# Nearest to will: would, base, can, amazonas, loser, must, aorta, webster,
# Nearest to world: bckgr, amazonas, trapezohedron, khanates, retroactively, solf, reginald, brave,
# Nearest to were: are, was, is, mishnayot, dasyprocta, had, invariably, nearer,
# Average loss at step  32000 :  5.995932330846786
# Average loss at step  34000 :  5.722420373916626
# Average loss at step  36000 :  5.778159278392792
# Average loss at step  38000 :  5.50402846622467
# Average loss at step  40000 :  5.262320540904999
# Nearest to about: ibelin, agouti, indie, reddy, six, three, five, sufficiently,
# Nearest to it: he, this, which, there, she, that, aba, zero,
# Nearest to but: and, tnf, circ, that, or, which, lymphoma, agouti,
# Nearest to during: in, from, on, untested, paintings, at, after, and,
# Nearest to not: it, paints, restaurant, to, also, zero, penning, avoided,
# Nearest to an: seen, cellist, the, completely, fifths, minoan, fitness, aorta,
# Nearest to than: or, inconsistent, humidity, dasyprocta, aluminum, agouti, torsion, defunct,
# Nearest to has: had, is, have, was, kool, were, meridians, bearers,
# Nearest to i: fuzes, he, douglas, lascaris, it, apc, astonishing, instructions,
# Nearest to he: it, they, she, who, i, zero, and, which,
# Nearest to into: from, luisa, in, to, resided, upon, decade, muller,
# Nearest to seven: eight, six, four, five, nine, zero, three, one,
# Nearest to often: also, which, sometimes, now, hillsides, continuity, not, copied,
# Nearest to will: would, can, must, base, to, amazonas, aorta, cajun,
# Nearest to world: bckgr, khanates, trapezohedron, amazonas, browed, dogs, angles, solf,
# Nearest to were: are, was, is, have, had, zero, be, in,
# Average loss at step  42000 :  5.390570569038391
# Average loss at step  44000 :  5.220324655175209
# Average loss at step  46000 :  5.235253095865249
# Average loss at step  48000 :  5.193123816728592
# Average loss at step  50000 :  5.002642628312111
# Nearest to about: ibelin, indie, agouti, reddy, sufficiently, six, heldenplatz, five,
# Nearest to it: he, this, there, which, she, aba, agouti, they,
# Nearest to but: and, tnf, circ, that, or, lymphoma, kapoor, however,
# Nearest to during: in, on, from, at, after, untested, paintings, mishnayot,
# Nearest to not: it, paints, also, restaurant, to, often, usually, still,
# Nearest to an: seen, cellist, completely, fifths, minoan, another, aorta, fitness,
# Nearest to than: or, inconsistent, humidity, agouti, dasyprocta, torsion, circ, for,
# Nearest to has: had, is, have, was, kool, having, meridians, sutra,
# Nearest to i: fuzes, he, douglas, astonishing, lascaris, apc, it, five,
# Nearest to he: it, they, she, who, i, tnf, faction, starships,
# Nearest to into: from, luisa, in, to, upon, resided, muller, decade,
# Nearest to seven: eight, six, five, four, three, nine, zero, one,
# Nearest to often: also, sometimes, now, which, not, commonly, continuity, no,
# Nearest to will: would, can, must, to, and, should, aorta, cajun,
# Nearest to world: bckgr, khanates, booed, trapezohedron, angles, amazonas, mediterranean, brave,
# Nearest to were: are, was, is, had, have, be, lascaris, dasyprocta,
# Average loss at step  52000 :  5.027169423818588
# Average loss at step  54000 :  5.1871491641998295
# Average loss at step  56000 :  5.0563237578868865
# Average loss at step  58000 :  5.0576968591213225
# Average loss at step  60000 :  4.945629084467888
# Nearest to about: ibelin, indie, reddy, six, five, agouti, sufficiently, four,
# Nearest to it: he, this, there, which, she, they, aba, agouti,
# Nearest to but: and, circ, tnf, however, or, lymphoma, that, while,
# Nearest to during: in, after, at, from, on, michelob, untested, mcduck,
# Nearest to not: it, paints, also, still, to, restaurant, usually, never,
# Nearest to an: seen, completely, minoan, cellist, fifths, another, aorta, borel,
# Nearest to than: or, inconsistent, humidity, agouti, dasyprocta, for, circ, torsion,
# Nearest to has: had, have, is, was, having, kool, meridians, lymphoma,
# Nearest to i: fuzes, he, douglas, lascaris, astonishing, apc, who, mcluhan,
# Nearest to he: it, they, she, who, i, starships, which, tnf,
# Nearest to into: from, luisa, upon, resided, through, muller, to, toga,
# Nearest to seven: eight, six, five, nine, four, three, zero, michelob,
# Nearest to often: sometimes, also, now, commonly, which, not, circ, racist,
# Nearest to will: would, can, must, to, should, cajun, might, aorta,
# Nearest to world: pulau, bckgr, khanates, michelob, booed, amazonas, trapezohedron, browed,
# Nearest to were: are, was, have, had, be, is, being, lascaris,
# Average loss at step  62000 :  4.996682044625282
# Average loss at step  64000 :  4.842779556632042
# Average loss at step  66000 :  4.60379717195034
# Average loss at step  68000 :  4.972482793807983
# Average loss at step  70000 :  4.895962382793426
# Nearest to about: ibelin, indie, reddy, sufficiently, agouti, emitted, three, afx,
# Nearest to it: he, this, there, she, which, they, what, aba,
# Nearest to but: and, circ, however, tnf, microcebus, while, or, lymphoma,
# Nearest to during: in, after, microcebus, at, from, michelob, mcduck, alphorn,
# Nearest to not: it, still, usually, they, paints, to, restaurant, also,
# Nearest to an: seen, completely, minoan, the, cellist, fifths, aorta, nantucket,
# Nearest to than: or, and, inconsistent, agouti, humidity, dasyprocta, circ, aircrew,
# Nearest to has: had, have, is, was, having, kool, lymphoma, akita,
# Nearest to i: fuzes, he, douglas, astonishing, lascaris, UNK, mcluhan, apc,
# Nearest to he: it, she, they, who, there, microcebus, starships, i,
# Nearest to into: from, luisa, upon, through, in, toga, resided, converges,
# Nearest to seven: six, eight, four, nine, five, three, zero, microcebus,
# Nearest to often: sometimes, also, now, commonly, generally, not, usually, which,
# Nearest to will: would, can, must, should, might, to, may, could,
# Nearest to world: pulau, bckgr, booed, khanates, browed, amazonas, michelob, angles,
# Nearest to were: are, was, have, had, be, microcebus, been, is,
# Average loss at step  72000 :  4.760032575964928
# Average loss at step  74000 :  4.810200870037079
# Average loss at step  76000 :  4.718038716197014
# Average loss at step  78000 :  4.8099410834312435
# Average loss at step  80000 :  4.8135865676403045
# Nearest to about: ibelin, indie, sufficiently, reddy, emitted, agouti, glamour, three,
# Nearest to it: he, there, this, she, which, they, what, aba,
# Nearest to but: and, however, circ, tnf, microcebus, while, or, lymphoma,
# Nearest to during: in, after, microcebus, at, from, michelob, including, mcduck,
# Nearest to not: still, usually, often, to, paints, never, it, they,
# Nearest to an: seen, completely, minoan, cellist, fifths, borel, nantucket, aorta,
# Nearest to than: or, inconsistent, and, agouti, humidity, dasyprocta, circ, thz,
# Nearest to has: had, have, is, was, having, lymphoma, akita, xk,
# Nearest to i: fuzes, he, UNK, astonishing, douglas, lascaris, ii, apc,
# Nearest to he: it, she, they, who, there, i, starships, we,
# Nearest to into: from, through, luisa, to, upon, toga, converges, resided,
# Nearest to seven: eight, six, five, four, nine, three, microcebus, one,
# Nearest to often: sometimes, commonly, now, also, usually, generally, not, still,
# Nearest to will: would, can, must, should, may, to, might, could,
# Nearest to world: bckgr, pulau, booed, khanates, browed, angles, solf, amazonas,
# Nearest to were: are, was, have, had, be, microcebus, been, dasyprocta,
# Average loss at step  82000 :  4.769526694059372
# Average loss at step  84000 :  4.743217596173286
# Average loss at step  86000 :  4.765715108633041
# Average loss at step  88000 :  4.748591662287712
# Average loss at step  90000 :  4.729207271575928
# Nearest to about: ibelin, indie, reddy, emitted, sufficiently, datum, agouti, adonijah,
# Nearest to it: he, this, there, she, which, they, what, agouti,
# Nearest to but: however, and, circ, tnf, while, microcebus, or, which,
# Nearest to during: in, after, microcebus, at, from, michelob, including, on,
# Nearest to not: still, usually, never, they, often, it, to, also,
# Nearest to an: seen, completely, minoan, cellist, nantucket, fifths, borel, dissipate,
# Nearest to than: or, qualcomm, inconsistent, agouti, but, humidity, and, beetle,
# Nearest to has: had, have, is, was, having, xk, akita, lymphoma,
# Nearest to i: he, fuzes, astonishing, ii, douglas, apc, lascaris, mcluhan,
# Nearest to he: it, she, they, who, there, we, starships, microcebus,
# Nearest to into: from, through, luisa, upon, toga, converges, on, resided,
# Nearest to seven: eight, five, six, four, nine, three, zero, microcebus,
# Nearest to often: sometimes, commonly, now, also, usually, generally, not, still,
# Nearest to will: would, can, must, should, may, might, could, to,
# Nearest to world: bckgr, pulau, booed, browed, khanates, globemaster, monologues, angles,
# Nearest to were: are, was, have, had, be, microcebus, by, been,
# Average loss at step  92000 :  4.669277212738991
# Average loss at step  94000 :  4.719044063925743
# Average loss at step  96000 :  4.699529140710831
# Average loss at step  98000 :  4.603828247785568
# Average loss at step  100000 :  4.686253892064094
# Nearest to about: ibelin, indie, three, datum, emitted, reddy, sufficiently, adonijah,
# Nearest to it: he, there, this, she, they, which, what, agouti,
# Nearest to but: however, and, circ, while, tnf, microcebus, although, which,
# Nearest to during: in, after, microcebus, at, michelob, from, including, but,
# Nearest to not: still, usually, they, never, often, it, generally, also,
# Nearest to an: seen, completely, minoan, cellist, fifths, nantucket, borel, fitness,
# Nearest to than: or, qualcomm, inconsistent, agouti, circ, but, rivals, beetle,
# Nearest to has: had, have, is, was, having, xk, akita, lymphoma,
# Nearest to i: he, douglas, ii, you, apc, astonishing, fuzes, lascaris,
# Nearest to he: it, she, they, there, who, we, starships, microcebus,
# Nearest to into: from, through, upon, luisa, toga, converges, on, resided,
# Nearest to seven: eight, six, five, four, nine, three, microcebus, zero,
# Nearest to often: sometimes, commonly, now, usually, also, generally, still, not,
# Nearest to will: would, can, must, may, should, could, might, to,
# Nearest to world: bckgr, pulau, booed, globemaster, browed, monologues, khanates, solf,
# Nearest to were: are, was, have, had, be, microcebus, being, is,
